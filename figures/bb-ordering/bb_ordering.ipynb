# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import re
import sys

sys.path.append(os.path.abspath("../../"))
from dataset import DS_NAMES
from dataset import DS_DIMENSIONS
from utilities.figure_tools import get_latest_results_directory, make_fig_directory, load_results

cmap = plt.get_cmap("Set1")
colors = cmap.colors

# %%
run_id, run_path = get_latest_results_directory("../../results/bb-ordering/")

manual_select = False
if manual_select:
    run_id = 5
    run_path = "C:/Users/Peter/Documents/Peter/9-Graduate-School/2-dsrg/explainable-ad/code/HEEAD/results/bb-ordering/run-{:003d}".format(run_id)
# fig_output_path = make_fig_directory(run_id)
found_ds, results = load_results(run_path, group_fields=["dataset", "order"])
print("Generating figures for run-{:03d}".format(run_id))
# Out:
# Generating figures for run-012

# %%
all_results = pd.DataFrame()
for ds in found_ds:
    all_results = pd.concat([all_results, results[ds]], ignore_index=True)
all_results = all_results.groupby(["dataset", "order"]).mean()
print(all_results.shape)
# Out:
# (10, 20)

# %%
all_results[["runtime", "ext_min", "ext_avg", "ext_max", "coverage_ratio", "mean_dist"]].head(20)
# Out:
#                            runtime  ext_min   ext_avg  ext_max  \
# dataset   order
# cancer    PriorityQueue  20.177447     4195  20085.85    58272
#           Stack          34.312846     1170   2083.85     4475
# glass     PriorityQueue   4.180999     1454   4893.40    10871
#           Stack           6.166057      446   1008.30     2219
# magic     PriorityQueue  11.194987     2920  14109.25    32791
#           Stack          17.520962      807   1864.85     3926
# spambase  PriorityQueue  23.114940     4255  16918.25    35722
#           Stack          54.040889     2054   3706.50     6220
# vertebral PriorityQueue   2.416008     1424   3577.65     8599
#           Stack           3.944976      312    916.05     2194
#
#                          coverage_ratio  mean_dist
# dataset   order
# cancer    PriorityQueue             1.0   0.142881
#           Stack                     1.0   0.142881
# glass     PriorityQueue             1.0   0.065975
#           Stack                     1.0   0.065975
# magic     PriorityQueue             1.0   0.093198
#           Stack                     1.0   0.093198
# spambase  PriorityQueue             1.0   0.004870
#           Stack                     1.0   0.004870
# vertebral PriorityQueue             1.0   0.113181
#           Stack                     1.0   0.113181
