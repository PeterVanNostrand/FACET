# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import re
import sys

sys.path.append(os.path.abspath("../../"))
from dataset import DS_NAMES
from dataset import DS_DIMENSIONS
from utilities.figure_tools import get_latest_results_directory, make_fig_directory, load_results

cmap = plt.get_cmap("Set1")
colors = cmap.colors

# %%
run_id, run_path = get_latest_results_directory("../../results/bb-ordering/")


# fig_output_path = make_fig_directory(run_id)
found_ds, results = load_results(run_path, group_fields=["dataset", "order"])
print("Generating figures for run-{:03d}".format(run_id))
# Out:
# Generating figures for run-029

# %%
all_results = pd.DataFrame()
for ds in found_ds:
    all_results = pd.concat([all_results, results[ds]], ignore_index=True)
all_results = all_results.groupby(["dataset", "order"]).mean()
print(all_results.shape)
# Out:
# (15, 26)

# %%
all_results.head()
# Out:
#                                n_samples  n_samples_explained  n_features  \
# dataset order
# cancer  ModifiedPriorityQueue        568                    5          30
#         PriorityQueue                568                    5          30
#         Stack                        568                    5          30
# glass   ModifiedPriorityQueue        162                    5           9
#         PriorityQueue                162                    5           9
#
#                                n_trees  max_depth  avg_nnodes  avg_nleaves  \
# dataset order
# cancer  ModifiedPriorityQueue       15          3   12.466667     6.733333
#         PriorityQueue               15          3   12.466667     6.733333
#         Stack                       15          3   12.466667     6.733333
# glass   ModifiedPriorityQueue       15          3   12.200000     6.600000
#         PriorityQueue               15          3   12.200000     6.600000
#
#                                avg_depth  accuracy  precision  ...   lb_avg  \
# dataset order                                                  ...
# cancer  ModifiedPriorityQueue        3.0  0.973684   0.973684  ...  39908.8
#         PriorityQueue                3.0  0.973684   0.973684  ...  34448.0
#         Stack                        3.0  0.973684   0.973684  ...  68358.2
# glass   ModifiedPriorityQueue        3.0  0.878788   0.833333  ...   8049.4
#         PriorityQueue                3.0  0.878788   0.833333  ...   7847.0
#
#                                lb_max  bt_min   bt_avg  bt_max  init_time  \
# dataset order
# cancer  ModifiedPriorityQueue   95824     250  18862.4   70694   0.158999
#         PriorityQueue           76588   15401  34448.0   76588   0.158999
#         Stack                  135004    5415  46603.2  101198   0.158999
# glass   ModifiedPriorityQueue   15796     188    785.8    1312   0.169817
#         PriorityQueue           15408    2144   7847.0   15408   0.169817
#
#                                  runtime  coverage_ratio  mean_dist  \
# dataset order
# cancer  ModifiedPriorityQueue   8.859155             1.0   0.152693
#         PriorityQueue           8.913577             1.0   0.152693
#         Stack                  15.696899             1.0   0.152693
# glass   ModifiedPriorityQueue   1.452426             1.0   0.186960
#         PriorityQueue           1.643504             1.0   0.186960
#
#                                mean_length
# dataset order
# cancer  ModifiedPriorityQueue          4.6
#         PriorityQueue                  4.6
#         Stack                          4.6
# glass   ModifiedPriorityQueue          2.0
#         PriorityQueue                  2.0
#
# [5 rows x 26 columns]

# %%
all_results["ext_lb"] = all_results["ext_avg"] / all_results["lb_avg"]
all_results["sample_time"] = all_results["runtime"] / all_results["n_samples_explained"]

# %%
all_results.head()
# Out:
#                                n_samples  n_samples_explained  n_features  \
# dataset order
# cancer  ModifiedPriorityQueue        568                    5          30
#         PriorityQueue                568                    5          30
#         Stack                        568                    5          30
# glass   ModifiedPriorityQueue        162                    5           9
#         PriorityQueue                162                    5           9
#
#                                n_trees  max_depth  avg_nnodes  avg_nleaves  \
# dataset order
# cancer  ModifiedPriorityQueue       15          3   12.466667     6.733333
#         PriorityQueue               15          3   12.466667     6.733333
#         Stack                       15          3   12.466667     6.733333
# glass   ModifiedPriorityQueue       15          3   12.200000     6.600000
#         PriorityQueue               15          3   12.200000     6.600000
#
#                                avg_depth  accuracy  precision  ...  bt_min  \
# dataset order                                                  ...
# cancer  ModifiedPriorityQueue        3.0  0.973684   0.973684  ...     250
#         PriorityQueue                3.0  0.973684   0.973684  ...   15401
#         Stack                        3.0  0.973684   0.973684  ...    5415
# glass   ModifiedPriorityQueue        3.0  0.878788   0.833333  ...     188
#         PriorityQueue                3.0  0.878788   0.833333  ...    2144
#
#                                 bt_avg  bt_max  init_time    runtime  \
# dataset order
# cancer  ModifiedPriorityQueue  18862.4   70694   0.158999   8.859155
#         PriorityQueue          34448.0   76588   0.158999   8.913577
#         Stack                  46603.2  101198   0.158999  15.696899
# glass   ModifiedPriorityQueue    785.8    1312   0.169817   1.452426
#         PriorityQueue           7847.0   15408   0.169817   1.643504
#
#                                coverage_ratio  mean_dist  mean_length  \
# dataset order
# cancer  ModifiedPriorityQueue             1.0   0.152693          4.6
#         PriorityQueue                     1.0   0.152693          4.6
#         Stack                             1.0   0.152693          4.6
# glass   ModifiedPriorityQueue             1.0   0.186960          2.0
#         PriorityQueue                     1.0   0.186960          2.0
#
#                                  ext_lb  sample_time
# dataset order
# cancer  ModifiedPriorityQueue  0.047488     1.771831
#         PriorityQueue          1.000029     1.782715
#         Stack                  0.053307     3.139380
# glass   ModifiedPriorityQueue  0.089746     0.290485
#         PriorityQueue          0.958354     0.328701
#
# [5 rows x 28 columns]

# %%
all_results["sln_max"] = all_results["bt_max"] / all_results["lb_max"]

# %%
all_results[["lb_min",
        "lb_avg",
        "lb_max",
        "bt_min",
        "bt_avg",
        "bt_max",
        "sample_time",
        "sln_max"]].head(20)
# Out:
#                                  lb_min   lb_avg  lb_max  bt_min   bt_avg  \
# dataset   order
# cancer    ModifiedPriorityQueue   15401  39908.8   95824     250  18862.4
#           PriorityQueue           15401  34448.0   76588   15401  34448.0
#           Stack                   20380  68358.2  135004    5415  46603.2
# glass     ModifiedPriorityQueue    2255   8049.4   15796     188    785.8
#           PriorityQueue            2144   7847.0   15408    2144   7847.0
#           Stack                    2623  10462.8   23974     514   4362.6
# magic     ModifiedPriorityQueue    3885  14093.4   38049     191    270.0
#           PriorityQueue            3885  14084.8   38049    3885  14084.8
#           Stack                    4730  19529.2   47269    1006   6950.2
# spambase  ModifiedPriorityQueue   14507  26209.8   45528     269   2681.6
#           PriorityQueue           14507  25269.0   45528   14507  25269.0
#           Stack                   21249  40626.8   58439    9453  25295.8
# vertebral ModifiedPriorityQueue    2545   5236.2    9016     178    940.4
#           PriorityQueue            2545   4880.2    9016    2545   4880.2
#           Stack                    4333   6914.2    9835     248   2548.6
#
#                                  bt_max  sample_time   sln_max
# dataset   order
# cancer    ModifiedPriorityQueue   70694     1.771831  0.737748
#           PriorityQueue           76588     1.782715  1.000000
#           Stack                  101198     3.139380  0.749593
# glass     ModifiedPriorityQueue    1312     0.290485  0.083059
#           PriorityQueue           15408     0.328701  1.000000
#           Stack                   16356     0.375114  0.682239
# magic     ModifiedPriorityQueue     324     0.512799  0.008515
#           PriorityQueue           38049     0.613754  1.000000
#           Stack                   10877     0.739493  0.230109
# spambase  ModifiedPriorityQueue   12034     1.573574  0.264321
#           PriorityQueue           45528     1.704397  1.000000
#           Stack                   37934     2.480642  0.649121
# vertebral ModifiedPriorityQueue    2571     0.187667  0.285160
#           PriorityQueue            9016     0.165775  1.000000
#           Stack                    4538     0.234733  0.461413

# %%
all_results[["runtime", "sample_time", "ext_min", "ext_avg", "ext_max", "lb_min", "lb_avg", "lb_max", "ext_lb", "coverage_ratio", "mean_dist"]].head(20)
# Out:
#                                    runtime  sample_time  ext_min  ext_avg  \
# dataset   order
# cancer    ModifiedPriorityQueue   8.859155     1.771831      795   1895.2
#           PriorityQueue           8.913577     1.782715    15402  34449.0
#           Stack                  15.696899     3.139380     1480   3644.0
# glass     ModifiedPriorityQueue   1.452426     0.290485      331    722.4
#           PriorityQueue           1.643504     0.328701     2129   7520.2
#           Stack                   1.875569     0.375114      432   1110.6
# magic     ModifiedPriorityQueue   2.563994     0.512799      348   1085.4
#           PriorityQueue           3.068768     0.613754     3632  13684.8
#           Stack                   3.697466     0.739493      747   1947.6
# spambase  ModifiedPriorityQueue   7.867872     1.573574      733   1153.2
#           PriorityQueue           8.521985     1.704397    13482  24560.8
#           Stack                  12.403211     2.480642     1307   2197.0
# vertebral ModifiedPriorityQueue   0.938333     0.187667      350    612.2
#           PriorityQueue           0.828876     0.165775     2522   4752.6
#           Stack                   1.173663     0.234733      512    930.4
#
#                                  ext_max  lb_min   lb_avg  lb_max    ext_lb  \
# dataset   order
# cancer    ModifiedPriorityQueue     4559   15401  39908.8   95824  0.047488
#           PriorityQueue            76589   15401  34448.0   76588  1.000029
#           Stack                     6768   20380  68358.2  135004  0.053307
# glass     ModifiedPriorityQueue     1427    2255   8049.4   15796  0.089746
#           PriorityQueue            15342    2144   7847.0   15408  0.958354
#           Stack                     2488    2623  10462.8   23974  0.106147
# magic     ModifiedPriorityQueue     2889    3885  14093.4   38049  0.077015
#           PriorityQueue            36722    3885  14084.8   38049  0.971601
#           Stack                     4168    4730  19529.2   47269  0.099728
# spambase  ModifiedPriorityQueue     1772   14507  26209.8   45528  0.043999
#           PriorityQueue            45529   14507  25269.0   45528  0.971974
#           Stack                     3041   21249  40626.8   58439  0.054078
# vertebral ModifiedPriorityQueue      823    2545   5236.2    9016  0.116917
#           PriorityQueue             8607    2545   4880.2    9016  0.973854
#           Stack                     1361    4333   6914.2    9835  0.134564
#
#                                  coverage_ratio  mean_dist
# dataset   order
# cancer    ModifiedPriorityQueue             1.0   0.152693
#           PriorityQueue                     1.0   0.152693
#           Stack                             1.0   0.152693
# glass     ModifiedPriorityQueue             1.0   0.186960
#           PriorityQueue                     1.0   0.186960
#           Stack                             1.0   0.186960
# magic     ModifiedPriorityQueue             1.0   0.080149
#           PriorityQueue                     1.0   0.080149
#           Stack                             1.0   0.080149
# spambase  ModifiedPriorityQueue             1.0   0.009738
#           PriorityQueue                     1.0   0.009738
#           Stack                             1.0   0.009738
# vertebral ModifiedPriorityQueue             1.0   0.076728
#           PriorityQueue                     1.0   0.076728
#           Stack                             1.0   0.076728
